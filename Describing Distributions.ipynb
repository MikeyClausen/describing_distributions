# %% [markdown]
# # Imports

# %%
#Imports
import os
os.environ["OMP_NUM_THREADS"] = '1'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
url='https://docs.google.com/spreadsheets/d/1APV3pXiAszS_0mSgkiEt9IUNH-QmyX7KwxSAwuADl6Y/gviz/tq?tqx=out:csv&sheet=medical_data'
df=pd.read_csv(url)
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
df.columns
# Out:
# Index(['State', 'Lat', 'Lng', 'Area', 'Children', 'Age', 'Income', 'Marital',
#        'Gender', 'ReAdmis', 'VitD_levels', 'Doc_visits', 'Full_meals_eaten',
#        'vitD_supp', 'Soft_drink', 'Initial_admin', 'HighBlood', 'Stroke',
#        'Complication_risk', 'Overweight', 'Arthritis', 'Diabetes',
#        'Hyperlipidemia', 'BackPain', 'Anxiety', 'Allergic_rhinitis',
#        'Reflux_esophagitis', 'Asthma', 'Services', 'Initial_days',
#        'TotalCharge', 'Additional_charges'],
#       dtype='object')

# %% [markdown]
# # VitD_levels

# %%
df['VitD_levels'].value_counts()
# Out:
# 19.141466    1
# 18.180901    1
# 21.097365    1
# 18.670625    1
# 18.988771    1
#             ..
# 13.306814    1
# 16.019013    1
# 14.088522    1
# 15.801872    1
# 19.487658    1
# Name: VitD_levels, Length: 1000, dtype: int64

# %%
col='VitD_levels'
feature=df[col]
mean=feature.mean()
median=feature.median()
std=feature.std()
plus1std=mean+std
minus1std=mean-std

# %%
sns.scatterplot(feature)
# Out:
# <AxesSubplot: ylabel='VitD_levels'>

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.histplot(feature,ax=ax,stat='density',kde=True)
ax.axvline(mean,color='red',label=f'Mean={mean:,.2f}')
ax.axvline(median,color='green',ls='--',label=f'Median={median:,.2f}')
ax.axvline(plus1std,color='black',label=f'+1 std={plus1std:,.2f}')
ax.axvline(minus1std,color='black',label= f'-1 std={minus1std:,.2f}')
ax.axvspan(plus1std,minus1std,color='yellow',zorder=0)
ax.set_title(col)
ax.legend();

# %%
kurt=stats.kurtosis(feature,fisher=False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# # Doc_visits

# %%
col='Doc_visits'
feature=df[col]
mean=feature.mean()
median=feature.median()
std=feature.std()
plus1std=mean+std
minus1std=mean-std

# %%
sns.scatterplot(feature)
# Out:
# <AxesSubplot: ylabel='Doc_visits'>

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.histplot(feature,ax=ax,discrete=True,stat='density',kde=True)
ax.axvline(mean,color='red',label=f'Mean={mean:,.2f}')
ax.axvline(median,color='green',ls='--',label=f'Median={median:,.2f}')
ax.axvline(plus1std,color='black',label=f'+1 std={plus1std:,.2f}')
ax.axvline(minus1std,color='black',label= f'-1 std={minus1std:,.2f}')
ax.axvspan(plus1std,minus1std,color='yellow',zorder=0)
ax.set_title(col)
ax.legend();

# %%
kurt=stats.kurtosis(feature,fisher=False)
kurt
# Out:
# 2.9919958083381206

# %% [markdown]
# # TotalCharge

# %%
col='TotalCharge'
feature=df[col]
mean=feature.mean()
median=feature.median()
std=feature.std()
plus1std=mean+std
minus1std=mean-std

# %%
sns.scatterplot(feature)
# Out:
# <AxesSubplot: ylabel='TotalCharge'>

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.histplot(feature,ax=ax,stat='density',kde=True)
ax.axvline(mean,color='red',label=f'Mean={mean:,.2f}')
ax.axvline(median,color='green',ls='--',label=f'Median={median:,.2f}')
ax.axvline(plus1std,color='black',label=f'+1 std={plus1std:,.2f}')
ax.axvline(minus1std,color='black',label= f'-1 std={minus1std:,.2f}')
ax.axvspan(plus1std,minus1std,color='yellow',zorder=0)
ax.set_title(col)
ax.legend();

# %%
kurt=stats.kurtosis(feature,fisher=False)
kurt
# Out:
# 3.2650077463439384

# %% [markdown]
# # Questions to answer

# %% [markdown]
# ## Answer the following questions:
# * Is it Discrete or Continuous?
# * Does it have a skew? If so, which direction (+/-)
# * What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)

# %% [markdown]
# ### Answers
# 1. VitD_levels = Continuous, Doc_visits = Discrete, TotalCharge = Continuous
#
# 2. VitD_levels = No skew, Doc_visits = No skew, TotalCharge = Positive skew
#
# 3. VitD_levels = Mesokurtic, Doc_visits = Platykurtic, TotalCharge = Leptokurtic
